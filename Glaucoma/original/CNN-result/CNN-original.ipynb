# %%
# %load CNN-original.py
"""
Created on Thu Sep 28 14:44:30 2017

@author: YUCHIH
"""
import numpy as np
import h5py as h5py
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.models import load_model
import matplotlib.pyplot as plt
import pandas as pd

#Initialize the CNN
classifier = Sequential()

#step1
classifier.add(Convolution2D(16,3,3,input_shape= (64,64,3), activation = 'relu'))

#step2
classifier.add(MaxPooling2D(pool_size = (2,2)))

#step1
classifier.add(Convolution2D(32,3,3, activation = 'relu'))

#step2
classifier.add(MaxPooling2D(pool_size = (2,2)))

#step1
classifier.add(Convolution2D(64,3,3, activation = 'relu'))

#step2
classifier.add(MaxPooling2D(pool_size = (2,2)))

#step1
classifier.add(Convolution2D(128,3,3, activation = 'relu'))

#step2
classifier.add(MaxPooling2D(pool_size = (2,2)))
#step3
classifier.add(Flatten())


#step4
classifier.add(Dense(output_dim = 100, activation = 'relu'))
classifier.add(Dropout(p=0.05))
classifier.add(Dense(output_dim = 1, activation = 'sigmoid'))

#compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# import OS
import os 

#setwd
os.chdir('C:/Users/xd944/Documents/20171212/original/CNN-result/')

from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(horizontal_flip=True)

training_set = train_datagen.flow_from_directory(
        'C:/Users/xd944/Documents/20171212/original/training/',
        target_size=(64,64),
        batch_size=12,
        class_mode='binary')

test_set = test_datagen.flow_from_directory(
        'C:/Users/xd944/Documents/20171212/original/testing/',
        target_size=(64,64),
        batch_size=32,
        class_mode='binary')
a = 1
for a in range(1,6):
    history = classifier.fit_generator(training_set,
            steps_per_epoch=24,
            epochs=20,
            validation_data=test_set,
            validation_steps=6)
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig("CNN_Accuracy_original_"+str(a)+".png")
    
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig("CNN_Loss_original_"+str(a)+".png")
    
    classifier.save('20171212_CNN_original_'+str(a)+'.h5')
    
    
    training_set.class_indices
    datapath = 'C:/Users/xd944/Documents/20171212/original/Predict/'
    #classifier = load_model('20171212_CNN_original.h5')
    
    
    from keras.preprocessing import image
    img_list = os.listdir(datapath)
        
    results = []
    for i in range(0,len(img_list),1):
        test_image = image.load_img(datapath + img_list[i],target_size=(64,64))
        test_image = image.img_to_array(test_image)
        test_image = np.expand_dims(test_image,axis = 0)
        results.append(classifier.predict(test_image))
        if results[i][0] == 0:
            prediction = 'Glaucoma'
        else:
            prediciton = 'Healthy'
        
    Final = np.hstack(results)
    Final = Final.T
    
    name_list = img_list
    i=0
    for i in range(0,len(img_list)):
        name_list[i] = img_list[i][0:9] #+ new[i][-8:]
        i=i+1
        
    Final_list = np.column_stack([name_list,Final])
    index = ['Row'+str(i) for i in range(1, len(Final_list)+1)]
    test = pd.DataFrame(data = Final_list[0:,0:],columns = ["ID","Prediction"],index=index)
    test = test.astype(dtype= {"ID":"object","Prediction":"float"})
    Final_list = pd.DataFrame(data = test.groupby(["ID"], as_index=False).mean())
    
    list_AB=[None]*len(Final_list)
    i=0
    for A in Final_list.iloc[0:,0]:
        list_AB[i] = A[0]
        i=i+1
            
    count_A = list_AB.count("A")
    count_B = list_AB.count("B")
    
    Final_list[Final_list["Prediction"] >= 0.5] = 1
    Final_list[Final_list["Prediction"] < 0.5] = 0
    
    H = count_A
    G = count_B
    Specificity = sum(Final_list.iloc[0:H,1])/H
    Sensitivity = 1 - sum(Final_list.iloc[H:len(Final_list),1])/G
    Accuracy = (Specificity*H + Sensitivity*G)/(H+G)
    print("Specificity: {}".format(Specificity))
    print("Sensitivity: {}".format(Sensitivity))
    print("Accuracy: {}".format(Accuracy))
    
    f = open("output_"+str(a)+'.txt',"w") #opens file with name of "test.txt"
    f.write("Sensitivity:"+ str(Sensitivity) +"\n")
    f.write("Specificity:"+ str(Specificity) + "\n")
    f.write("Accuracy:"+  str(Accuracy))
    f.close()
# Out:
# C:\Users\xd944\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (3, 3), activation="relu", input_shape=(64, 64, 3...)`
# C:\Users\xd944\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu")`
# C:\Users\xd944\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:35: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# C:\Users\xd944\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
# C:\Users\xd944\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:50: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=100)`
# C:\Users\xd944\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:51: UserWarning: Update your `Dropout` call to the Keras 2 API: `Dropout(rate=0.05)`
# C:\Users\xd944\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:52: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1)`
# Found 482 images belonging to 2 classes.
# Found 196 images belonging to 2 classes.
# Epoch 1/20
# 24/24 [==============================] - 11s 438ms/step - loss: 0.6000 - acc: 0.8576 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 2/20
# 24/24 [==============================] - 6s 271ms/step - loss: 0.3842 - acc: 0.9207 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 3/20
# 24/24 [==============================] - 6s 263ms/step - loss: 0.3561 - acc: 0.8887 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 4/20
# 24/24 [==============================] - 7s 277ms/step - loss: 0.2947 - acc: 0.9165 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 5/20
# 24/24 [==============================] - 7s 286ms/step - loss: 0.3127 - acc: 0.8993 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 6/20
# 24/24 [==============================] - 8s 342ms/step - loss: 0.3173 - acc: 0.9097 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 7/20
# 24/24 [==============================] - 7s 276ms/step - loss: 0.2987 - acc: 0.9131 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 8/20
# 24/24 [==============================] - 6s 268ms/step - loss: 0.2478 - acc: 0.9236 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 9/20
# 24/24 [==============================] - 6s 243ms/step - loss: 0.3436 - acc: 0.8781 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 10/20
# 24/24 [==============================] - 6s 250ms/step - loss: 0.2656 - acc: 0.9167 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 11/20
# 24/24 [==============================] - 8s 327ms/step - loss: 0.2990 - acc: 0.8993 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 12/20
# 24/24 [==============================] - 6s 267ms/step - loss: 0.2448 - acc: 0.9131 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 13/20
# 24/24 [==============================] - 7s 290ms/step - loss: 0.3021 - acc: 0.9026 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 14/20
# 24/24 [==============================] - 7s 276ms/step - loss: 0.2775 - acc: 0.9097 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 15/20
# 24/24 [==============================] - 7s 279ms/step - loss: 0.2578 - acc: 0.9165 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 16/20
# 24/24 [==============================] - 8s 314ms/step - loss: 0.2673 - acc: 0.8783 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 17/20
# 24/24 [==============================] - 7s 297ms/step - loss: 0.2202 - acc: 0.9167 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 18/20
# 24/24 [==============================] - 9s 367ms/step - loss: 0.1890 - acc: 0.9063 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 19/20
# 24/24 [==============================] - 7s 279ms/step - loss: 0.1703 - acc: 0.8928 - val_loss: 1.4489 - val_acc: 0.8958
# Epoch 20/20
# 24/24 [==============================] - 7s 278ms/step - loss: 0.1972 - acc: 0.9236 - val_loss: 1.3432 - val_acc: 0.9167
# dict_keys(['loss', 'val_acc', 'val_loss', 'acc'])
# Specificity: 0.0
# Sensitivity: 1.0
# Accuracy: 0.75
# Epoch 1/20
# 24/24 [==============================] - 9s 375ms/step - loss: 0.1326 - acc: 0.9340 - val_loss: 1.7579 - val_acc: 0.8906
# Epoch 2/20
# 24/24 [==============================] - 7s 277ms/step - loss: 0.1759 - acc: 0.9164 - val_loss: 1.5833 - val_acc: 0.9010
# Epoch 3/20
# 24/24 [==============================] - 7s 279ms/step - loss: 0.1240 - acc: 0.9236 - val_loss: 2.0877 - val_acc: 0.8698
# Epoch 4/20
# 24/24 [==============================] - 7s 293ms/step - loss: 0.1688 - acc: 0.9165 - val_loss: 3.0875 - val_acc: 0.7969
# Epoch 5/20
# 24/24 [==============================] - 7s 279ms/step - loss: 0.1369 - acc: 0.9410 - val_loss: 1.6766 - val_acc: 0.8958
# Epoch 6/20
# 24/24 [==============================] - 8s 350ms/step - loss: 0.1215 - acc: 0.9513 - val_loss: 1.7096 - val_acc: 0.8906
# Epoch 7/20
# 24/24 [==============================] - 7s 286ms/step - loss: 0.1191 - acc: 0.9374 - val_loss: 2.1155 - val_acc: 0.8646
# Epoch 8/20
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1031 - acc: 0.9479 - val_loss: 2.9496 - val_acc: 0.8021
# Epoch 9/20
# 24/24 [==============================] - 7s 289ms/step - loss: 0.1454 - acc: 0.9478 - val_loss: 1.8405 - val_acc: 0.8854
# Epoch 10/20
# 24/24 [==============================] - 7s 274ms/step - loss: 0.0937 - acc: 0.9549 - val_loss: 2.1717 - val_acc: 0.8646
# Epoch 11/20
# 24/24 [==============================] - 8s 321ms/step - loss: 0.1147 - acc: 0.9347 - val_loss: 1.5904 - val_acc: 0.9010
# Epoch 12/20
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1098 - acc: 0.9375 - val_loss: 2.0065 - val_acc: 0.8698
# Epoch 13/20
# 24/24 [==============================] - 7s 293ms/step - loss: 0.1136 - acc: 0.9514 - val_loss: 2.3350 - val_acc: 0.8542
# Epoch 14/20
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1322 - acc: 0.9513 - val_loss: 3.6915 - val_acc: 0.7656
# Epoch 15/20
# 24/24 [==============================] - 7s 282ms/step - loss: 0.1543 - acc: 0.9173 - val_loss: 2.1992 - val_acc: 0.8594
# Epoch 16/20
# 24/24 [==============================] - 8s 321ms/step - loss: 0.1006 - acc: 0.9513 - val_loss: 1.9403 - val_acc: 0.8750
# Epoch 17/20
# 24/24 [==============================] - 7s 304ms/step - loss: 0.0806 - acc: 0.9653 - val_loss: 2.0886 - val_acc: 0.8698
# Epoch 18/20
# 24/24 [==============================] - 10s 409ms/step - loss: 0.1038 - acc: 0.9444 - val_loss: 2.4144 - val_acc: 0.8490
# Epoch 19/20
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1076 - acc: 0.9513 - val_loss: 1.9598 - val_acc: 0.8750
# Epoch 20/20
# 24/24 [==============================] - 7s 293ms/step - loss: 0.0736 - acc: 0.9652 - val_loss: 1.7565 - val_acc: 0.8906
# dict_keys(['loss', 'val_acc', 'val_loss', 'acc'])
# Specificity: 0.5833333333333334
# Sensitivity: 1.0
# Accuracy: 0.8958333333333334
# Epoch 1/20
# 24/24 [==============================] - 9s 379ms/step - loss: 0.0736 - acc: 0.9722 - val_loss: 1.8821 - val_acc: 0.8802
# Epoch 2/20
# 24/24 [==============================] - 7s 295ms/step - loss: 0.1234 - acc: 0.9375 - val_loss: 2.0641 - val_acc: 0.8646
# Epoch 3/20
# 24/24 [==============================] - 7s 277ms/step - loss: 0.0784 - acc: 0.9652 - val_loss: 1.8267 - val_acc: 0.8854
# Epoch 4/20
# 24/24 [==============================] - 7s 293ms/step - loss: 0.0737 - acc: 0.9688 - val_loss: 1.9582 - val_acc: 0.8750
# Epoch 5/20
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1062 - acc: 0.9478 - val_loss: 2.0056 - val_acc: 0.8750
# Epoch 6/20
# 24/24 [==============================] - 9s 368ms/step - loss: 0.0889 - acc: 0.9583 - val_loss: 1.9476 - val_acc: 0.8750
# Epoch 7/20
# 24/24 [==============================] - 7s 288ms/step - loss: 0.0645 - acc: 0.9756 - val_loss: 2.5859 - val_acc: 0.8385
# Epoch 8/20
# 24/24 [==============================] - 7s 299ms/step - loss: 0.0834 - acc: 0.9653 - val_loss: 1.8135 - val_acc: 0.8802
# Epoch 9/20
# 24/24 [==============================] - 7s 303ms/step - loss: 0.0589 - acc: 0.9791 - val_loss: 2.0863 - val_acc: 0.8698
# Epoch 10/20
# 24/24 [==============================] - 7s 283ms/step - loss: 0.0528 - acc: 0.9826 - val_loss: 1.4704 - val_acc: 0.9062
# Epoch 11/20
# 24/24 [==============================] - 8s 343ms/step - loss: 0.0544 - acc: 0.9826 - val_loss: 1.7529 - val_acc: 0.8906
# Epoch 12/20
# 24/24 [==============================] - 7s 296ms/step - loss: 0.1033 - acc: 0.9513 - val_loss: 1.8405 - val_acc: 0.8854
# Epoch 13/20
# 24/24 [==============================] - 7s 284ms/step - loss: 0.0509 - acc: 0.9722 - val_loss: 2.6673 - val_acc: 0.8333
# Epoch 14/20
# 24/24 [==============================] - 7s 297ms/step - loss: 0.0920 - acc: 0.9618 - val_loss: 1.7717 - val_acc: 0.8854
# Epoch 15/20
# 24/24 [==============================] - 7s 280ms/step - loss: 0.0648 - acc: 0.9722 - val_loss: 2.2529 - val_acc: 0.8594
# Epoch 16/20
# 24/24 [==============================] - 8s 318ms/step - loss: 0.0420 - acc: 0.9896 - val_loss: 2.0896 - val_acc: 0.8698
# Epoch 17/20
# 24/24 [==============================] - 7s 280ms/step - loss: 0.0535 - acc: 0.9757 - val_loss: 1.6918 - val_acc: 0.8906
# Epoch 18/20
# 24/24 [==============================] - 9s 372ms/step - loss: 0.0900 - acc: 0.9687 - val_loss: 2.0681 - val_acc: 0.8698
# Epoch 19/20
# 24/24 [==============================] - 7s 288ms/step - loss: 0.0609 - acc: 0.9722 - val_loss: 2.3243 - val_acc: 0.8542
# Epoch 20/20
# 24/24 [==============================] - 7s 298ms/step - loss: 0.0485 - acc: 0.9826 - val_loss: 1.9226 - val_acc: 0.8802
# dict_keys(['loss', 'val_acc', 'val_loss', 'acc'])
# Specificity: 0.75
# Sensitivity: 1.0
# Accuracy: 0.9375
# Epoch 1/20
# 24/24 [==============================] - 9s 383ms/step - loss: 0.0472 - acc: 0.9791 - val_loss: 2.3720 - val_acc: 0.8490
# Epoch 2/20
# 24/24 [==============================] - 7s 292ms/step - loss: 0.0725 - acc: 0.9688 - val_loss: 1.8405 - val_acc: 0.8854
# Epoch 3/20
# 24/24 [==============================] - 7s 282ms/step - loss: 0.1643 - acc: 0.9277 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 4/20
# 24/24 [==============================] - 7s 310ms/step - loss: 0.1407 - acc: 0.9444 - val_loss: 1.3803 - val_acc: 0.9115
# Epoch 5/20
# 24/24 [==============================] - 7s 292ms/step - loss: 0.1036 - acc: 0.9513 - val_loss: 3.4493 - val_acc: 0.7760
# Epoch 6/20
# 24/24 [==============================] - 8s 351ms/step - loss: 0.1007 - acc: 0.9444 - val_loss: 2.1271 - val_acc: 0.8646
# Epoch 7/20
# 24/24 [==============================] - 7s 282ms/step - loss: 0.1081 - acc: 0.9549 - val_loss: 2.3377 - val_acc: 0.8542
# Epoch 8/20
# 24/24 [==============================] - 7s 285ms/step - loss: 0.0738 - acc: 0.9688 - val_loss: 2.4664 - val_acc: 0.8438
# Epoch 9/20
# 24/24 [==============================] - 7s 274ms/step - loss: 0.0762 - acc: 0.9721 - val_loss: 2.0886 - val_acc: 0.8698
# Epoch 10/20
# 24/24 [==============================] - 7s 277ms/step - loss: 0.0717 - acc: 0.9757 - val_loss: 2.5954 - val_acc: 0.8333
# Epoch 11/20
# 24/24 [==============================] - 8s 321ms/step - loss: 0.0499 - acc: 0.9861 - val_loss: 1.9226 - val_acc: 0.8802
# Epoch 12/20
# 24/24 [==============================] - 7s 294ms/step - loss: 0.0514 - acc: 0.9792 - val_loss: 1.9226 - val_acc: 0.8802
# Epoch 13/20
# 24/24 [==============================] - 7s 281ms/step - loss: 0.0364 - acc: 0.9896 - val_loss: 2.5850 - val_acc: 0.8385
# Epoch 14/20
# 24/24 [==============================] - 6s 267ms/step - loss: 0.1048 - acc: 0.9520 - val_loss: 2.9153 - val_acc: 0.8177
# Epoch 15/20
# 24/24 [==============================] - 6s 254ms/step - loss: 0.0933 - acc: 0.9688 - val_loss: 2.3377 - val_acc: 0.8542
# Epoch 16/20
# 24/24 [==============================] - 7s 280ms/step - loss: 0.0691 - acc: 0.9757 - val_loss: 2.8257 - val_acc: 0.8229
# Epoch 17/20
# 24/24 [==============================] - 6s 240ms/step - loss: 0.0668 - acc: 0.9757 - val_loss: 1.7574 - val_acc: 0.8906
# Epoch 18/20
# 24/24 [==============================] - 8s 315ms/step - loss: 0.0744 - acc: 0.9688 - val_loss: 2.4180 - val_acc: 0.8490
# Epoch 19/20
# 24/24 [==============================] - 6s 252ms/step - loss: 0.0476 - acc: 0.9861 - val_loss: 2.4474 - val_acc: 0.8438
# Epoch 20/20
# 24/24 [==============================] - 6s 246ms/step - loss: 0.0496 - acc: 0.9861 - val_loss: 1.9676 - val_acc: 0.8750
# dict_keys(['loss', 'val_acc', 'val_loss', 'acc'])
# Specificity: 0.6666666666666666
# Sensitivity: 1.0
# Accuracy: 0.9166666666666666
# Epoch 1/20
# 24/24 [==============================] - 8s 345ms/step - loss: 0.0372 - acc: 0.9861 - val_loss: 2.0877 - val_acc: 0.8698
# Epoch 2/20
# 24/24 [==============================] - 6s 254ms/step - loss: 0.1054 - acc: 0.9618 - val_loss: 1.3377 - val_acc: 0.9167
# Epoch 3/20
# 24/24 [==============================] - 6s 251ms/step - loss: 0.0643 - acc: 0.9757 - val_loss: 2.3428 - val_acc: 0.8490
# Epoch 4/20
# 24/24 [==============================] - 6s 262ms/step - loss: 0.0508 - acc: 0.9757 - val_loss: 1.9226 - val_acc: 0.8802
# Epoch 5/20
# 24/24 [==============================] - 6s 248ms/step - loss: 0.0495 - acc: 0.9826 - val_loss: 1.9462 - val_acc: 0.8750
# Epoch 6/20
# 24/24 [==============================] - 7s 312ms/step - loss: 0.0302 - acc: 0.9896 - val_loss: 1.8104 - val_acc: 0.8854
# Epoch 7/20
# 24/24 [==============================] - 6s 269ms/step - loss: 0.0313 - acc: 0.9931 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 8/20
# 24/24 [==============================] - 6s 248ms/step - loss: 0.0391 - acc: 0.9896 - val_loss: 2.2547 - val_acc: 0.8594
# Epoch 9/20
# 24/24 [==============================] - 6s 251ms/step - loss: 0.0226 - acc: 0.9965 - val_loss: 1.4253 - val_acc: 0.9115
# Epoch 10/20
# 24/24 [==============================] - 6s 245ms/step - loss: 0.0384 - acc: 0.9861 - val_loss: 1.7574 - val_acc: 0.8906
# Epoch 11/20
# 24/24 [==============================] - 7s 300ms/step - loss: 0.0447 - acc: 0.9792 - val_loss: 1.3432 - val_acc: 0.9167
# Epoch 12/20
# 24/24 [==============================] - 6s 266ms/step - loss: 0.1022 - acc: 0.9791 - val_loss: 2.1866 - val_acc: 0.8594
# Epoch 13/20
# 24/24 [==============================] - 6s 262ms/step - loss: 0.0721 - acc: 0.9688 - val_loss: 2.0891 - val_acc: 0.8698
# Epoch 14/20
# 24/24 [==============================] - 6s 245ms/step - loss: 0.0371 - acc: 0.9826 - val_loss: 1.9235 - val_acc: 0.8802
# Epoch 15/20
# 24/24 [==============================] - 6s 242ms/step - loss: 0.0610 - acc: 0.9722 - val_loss: 1.5083 - val_acc: 0.9062
# Epoch 16/20
# 24/24 [==============================] - 7s 278ms/step - loss: 0.0534 - acc: 0.9757 - val_loss: 1.7682 - val_acc: 0.8854
# Epoch 17/20
# 24/24 [==============================] - 6s 255ms/step - loss: 0.0361 - acc: 0.9930 - val_loss: 1.5914 - val_acc: 0.9010
# Epoch 18/20
# 24/24 [==============================] - 8s 332ms/step - loss: 0.0399 - acc: 0.9896 - val_loss: 1.8587 - val_acc: 0.8802
# Epoch 19/20
# 24/24 [==============================] - 6s 250ms/step - loss: 0.0225 - acc: 0.9930 - val_loss: 1.6848 - val_acc: 0.8906
# Epoch 20/20
# 24/24 [==============================] - 6s 244ms/step - loss: 0.0338 - acc: 0.9896 - val_loss: 2.6700 - val_acc: 0.8333
# dict_keys(['loss', 'val_acc', 'val_loss', 'acc'])
# Specificity: 0.6666666666666666
# Sensitivity: 0.8888888888888888
# Accuracy: 0.8333333333333334
