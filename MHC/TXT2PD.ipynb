# %%
import pandas as pd

# %%
def read_train_test(typ, N_FOLD):
  train = pd.read_csv('./Data/MHCPanII/{}{}.txt'.format(typ,N_FOLD), sep="\t", header=None)
  train.columns = ['peptide', 'aff', 'hla']
  
  return train

# %%
a = read_train_test('train',5)

# %%
b
# Out:
#                     peptide       aff                    hla
# 0           AAGVPPADKYRTFVA  0.081507  HLA-DPA10103-DPB10201
# 1           AALAAAAGVPPADKY  0.045988  HLA-DPA10103-DPB10201
# 2           AATAAAAAAVDRGDP  0.000000  HLA-DPA10103-DPB10201
# 3           AAVLFAATAAAAAAV  0.161833  HLA-DPA10103-DPB10201
# 4           AAWGGSGSEAYQGVQ  0.480544  HLA-DPA10103-DPB10201
# 5           AAYKLAYKTAEGATP  0.254349  HLA-DPA10103-DPB10201
# 6           AEGGKATTEEQKLIE  0.000000  HLA-DPA10103-DPB10201
# 7           AGDGDVVAVDIKEKG  0.000000  HLA-DPA10103-DPB10201
# 8           AGIMIFDPYGATISA  0.274684  HLA-DPA10103-DPB10201
# 9           AGKATTEEQKLIEKI  0.076722  HLA-DPA10103-DPB10201
# 10          AGSLQGQWRGAAGTA  0.125215  HLA-DPA10103-DPB10201
# 11          ANWIEIMRIKKLTIT  0.337314  HLA-DPA10103-DPB10201
# 12          APEDKYEAFVLHFSE  0.389017  HLA-DPA10103-DPB10201
# 13          APGDSPNTDGIHIGD  0.000000  HLA-DPA10103-DPB10201
# 14          ARVTVKDVTFRNITG  0.664046  HLA-DPA10103-DPB10201
# 15          ASEGAVDIINRWQVV  0.607340  HLA-DPA10103-DPB10201
# 16          ATAAAAAAVDRGDPP  0.000000  HLA-DPA10103-DPB10201
# 17          ATTEEQKLIEDINAS  0.170536  HLA-DPA10103-DPB10201
# 18          ATTEEQKLIEDVNAS  0.124501  HLA-DPA10103-DPB10201
# 19          AVQVTFTVQKGSDPK  0.247645  HLA-DPA10103-DPB10201
# 20          AVWGKNSCAKNYNCK  0.034027  HLA-DPA10103-DPB10201
# 21          AYKTAEGATPEAKYD  0.000000  HLA-DPA10103-DPB10201
# 22          CSGEPVVVHITDDNE  0.000000  HLA-DPA10103-DPB10201
# 23          DDLMIRVIAQGPTAT  0.000000  HLA-DPA10103-DPB10201
# 24          DKGPGFVVTGRVYCD  0.041247  HLA-DPA10103-DPB10201
# 25          EAGKATTEEQKLIED  0.220318  HLA-DPA10103-DPB10201
# 26          ECGGILQAYDLRDAP  0.340202  HLA-DPA10103-DPB10201
# 27          EGKQSLTKLAAAWGG  0.027083  HLA-DPA10103-DPB10201
# 28          EHGSDEWVAMTKGEG  0.036738  HLA-DPA10103-DPB10201
# 29          EKDVTDITVKNCVLK  0.069389  HLA-DPA10103-DPB10201
# ...                     ...       ...                    ...
# 24264       SHDVLTVQFLILGML  0.000000                H-2-IEd
# 24265       YAGIRRDGLLLRLVD  0.341006                H-2-IEd
# 24266       YNAVLTHVKINDKCP  0.089402                H-2-IEd
# 24267       YQLFSDAKANCTAES  0.124602                H-2-IEd
# 24268       AIDLPTHENHGLKTR  0.028735                H-2-IEd
# 24269       AQGKTLGVNMVRRGV  0.102736                H-2-IEd
# 24270       FFLFNILTGKKITAH  0.362305                H-2-IEd
# 24271       GINTRNMTMSMSMIL  0.254465                H-2-IEd
# 24272       GKKITAHLKRLWKML  0.448826                H-2-IEd
# 24273       GLSSRKRRSHDVLTV  0.121755                H-2-IEd
# 24274       IRAWVAWRAHCQNRD  0.568122                H-2-IEd
# 24275       LAVLRKVKRVVASLM  0.354364                H-2-IEd
# 24276       LIWVGINTRNMTMSM  0.042976                H-2-IEd
# 24277       NILTGKKITAHLKRL  0.166709                H-2-IEd
# 24278       RKRRSHDVLTVQFLI  0.114664                H-2-IEd
# 24279       RKVCYNAVLTHVKIN  0.205563                H-2-IEd
# 24280       RKVKRVVASLMRGLS  0.185943                H-2-IEd
# 24281       RVVASLMRGLSSRKR  0.421645                H-2-IEd
# 24282       SGGVWREMHHLVEFE  0.069963                H-2-IEd
# 24283      QVPLVQQQQYLGQQQP  0.172991                H-2-IEd
# 24284      AWRAHCQNRDLSQYIR  0.191673                H-2-IEd
# 24285    IFKLGGRDSRSGSPMARR  0.000000                H-2-IEd
# 24286  AYDAQGTLSKIFKLGGRDSR  0.030361                H-2-IEd
# 24287            DYGILQIKSR  0.000000                H-2-IEk
# 24288         AAIKAAAAAARAA  0.527627                H-2-IEk
# 24289         FEAQGAKANIAVD  0.000000                H-2-IEk
# 24290        EEDIEIIPIQEEEY  0.072792                H-2-IEk
# 24291       AAHSAAFEDLRVSSY  0.052982                H-2-IEk
# 24292       YAGIRRDGLLLRLVD  0.441317                H-2-IEk
# 24293      QVPLVQQQQYLGQQQP  0.450627                H-2-IEk
#
# [24294 rows x 3 columns]
